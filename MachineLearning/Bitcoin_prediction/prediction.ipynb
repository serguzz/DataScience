# %%
import yfinance as yf
import os
import pandas as pd

# %%
btc_ticker = yf.Ticker("BTC-USD")

# %%
if os.path.exists("btc.csv"):
    btc = pd.read_csv("btc.csv", index_col=0)
else:
    btc = btc_ticker.history(period="max")
    btc.to_csv("btc.csv")

# %%
btc
# Out:
#                     Open          High           Low         Close
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015  \
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2022-09-04  19832.470703  19999.689453  19636.816406  19986.712891
# 2022-09-05  19988.789062  20031.160156  19673.046875  19812.371094
# 2022-09-06  19817.724609  20155.269531  18800.171875  18837.667969
# 2022-09-07  18837.683594  19427.171875  18644.466797  19290.324219
# 2022-09-08  19309.482422  19410.619141  19089.548828  19337.371094
#
#                  Volume  Dividends  Stock Splits
# Date
# 2014-09-17     21056800          0             0
# 2014-09-18     34483200          0             0
# ...

# %%
btc.index = pd.to_datetime(btc.index)

# %%
del btc["Dividends"]
del btc["Stock Splits"]

# %%
btc.columns = [c.lower() for c in btc.columns]  # column names to lowercase

# %%
# btc

# %%
btc.plot.line(y="close", use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
# we'll combine historical price data with wiki edits santiment data
wiki = pd.read_csv("wikipedia_edits.csv", index_col=0, parse_dates=True)

# %%
wiki
# Out:
#             edit_count  sentiment  neg_sentiment
# 2009-04-06    0.133333  -0.018351       0.025000
# 2009-04-07    0.000000   0.000000       0.000000
# 2009-04-08    0.000000   0.000000       0.000000
# 2009-04-09    0.000000   0.000000       0.000000
# 2009-04-10    0.000000   0.000000       0.000000
# ...                ...        ...            ...
# 2022-09-04    0.400000  -0.108480       0.150000
# 2022-09-05    0.400000  -0.108480       0.150000
# 2022-09-06    0.433333  -0.081502       0.150000
# 2022-09-07    0.433333  -0.081502       0.150000
# 2022-09-08    0.466667  -0.114104       0.183333
#
# [4904 rows x 3 columns]

# %%
btc = btc.merge(wiki, left_index=True, right_index=True)

# %%
btc
# the earlier data is removed !!
# the rows where there is no match are ignored
# Out:
#                     open          high           low         close
# 2014-09-17    465.864014    468.174011    452.421997    457.334015  \
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2022-09-04  19832.470703  19999.689453  19636.816406  19986.712891
# 2022-09-05  19988.789062  20031.160156  19673.046875  19812.371094
# 2022-09-06  19817.724609  20155.269531  18800.171875  18837.667969
# 2022-09-07  18837.683594  19427.171875  18644.466797  19290.324219
# 2022-09-08  19309.482422  19410.619141  19089.548828  19337.371094
#
#                  volume  edit_count  sentiment  neg_sentiment
# 2014-09-17     21056800    5.033333  -0.232191       0.532718
# ...

# %%
# We will try to predict whether the price will go up or down.
# Not the actual price, but the DIRECTION OF THE PRICE.

# %%
btc["tomorrow"] = btc["close"].shift(-1)

# %%
# out 'target' - whether the price increased from yesterday or not 
btc["target"] = (btc["tomorrow"] > btc["close"]).astype(int)

# %%
btc["target"].value_counts()
# the price increased 1560 times out of 2900
# Out:
# target
# 1    1563
# 0    1351
# Name: count, dtype: int64

# %%
# Training our model

# out base-line model is RandomForestClassifier

from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, min_samples_split=50, random_state=1)

# last 200 days is a test set
# !! We cannot use cross validation in time sequenses !!!
train = btc.iloc[:-200]
test = btc.iloc[-200:]

# specify the predictors
predictors = ["close", "volume", "open", "high", "low", "edit_count", "sentiment", "neg_sentiment"]
model.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=50, random_state=1)

# %%
# Validate our model with precision_score  from sklearn.metrics
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])
preds = pd.Series(preds, index=test.index)
precision_score(test["target"], preds)
# Out:
# 0.48484848484848486

# %%
# Evaluating error with backtesting

# predict function returns predictions and actual values (all in one DataFrame)

def predict(train, test, predictors, model):
    model.fit(train[predictors], train["target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="predictions")
    combined = pd.concat([test["target"], preds], axis=1)
    return combined

# %%
# backtest function does predictions of last periods

def backtest(data, model, predictors, start=1095, step=150):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    
    return pd.concat(all_predictions)

# %%
# we'll upgrade our RFC (RandomForestClassifier) model with XGBClassifier

from xgboost import XGBClassifier

model = XGBClassifier(random_state=1, learning_rate=.1, n_estimators=200)
predictions = backtest(btc, model, predictors)

# %%
predictions["predictions"].value_counts()
# Out:
# predictions
# 1    1084
# 0     735
# Name: count, dtype: int64

# %%
precision_score(predictions["target"], predictions["predictions"])

# We can see:
# XGBoost improoved our model from 48.5% to 50%
# Out:
# 0.5009225092250923

# %%
# We'll try to improove our model using only 'close', 'sentiment', 'neg_sentiment' columns
# and their trends and rolling averages

def compute_rolling(btc):
    horizons = [2,7,60,365]
    new_predictors = ["close", "sentiment", "neg_sentiment"]

    for horizon in horizons:
        rolling_averages = btc.rolling(horizon, min_periods=1).mean()

        ratio_column = f"close_ratio_{horizon}"
        btc[ratio_column] = btc["close"] / rolling_averages["close"]
        
        edit_column = f"edit_{horizon}"
        btc[edit_column] = rolling_averages["edit_count"]

        rolling = btc.rolling(horizon, closed='left', min_periods=1).mean()
        trend_column = f"trend_{horizon}"
        btc[trend_column] = rolling["target"]

        new_predictors+= [ratio_column, trend_column, edit_column]
    return btc, new_predictors

# %%
btc, new_predictors = compute_rolling(btc.copy())

# %%
btc.head()
# Out:
#                   open        high         low       close    volume
# 2014-09-17  465.864014  468.174011  452.421997  457.334015  21056800  \
# 2014-09-18  456.859985  456.859985  413.104004  424.440002  34483200
# 2014-09-19  424.102997  427.834991  384.532013  394.795990  37919700
# 2014-09-20  394.673004  423.295990  389.882996  408.903992  36863600
# 2014-09-21  408.084991  412.425995  393.181000  398.821014  26580100
#
#             edit_count  sentiment  neg_sentiment    tomorrow  target  ...
# 2014-09-17    5.033333  -0.232191       0.532718  424.440002       0  ...  \
# 2014-09-18    5.066667  -0.232759       0.532718  394.795990       0  ...
# 2014-09-19    5.200000  -0.235415       0.549385  408.903992       1  ...
# 2014-09-20    5.200000  -0.233185       0.549385  398.821014       0  ...
# 2014-09-21    5.233333  -0.204017       0.532718  402.152008       1  ...
#
#             trend_2  close_ratio_7    edit_7   trend_7  close_ratio_60
# ...

# %%
predictions = backtest(btc, model, new_predictors)

# %%
precision_score(predictions["target"], predictions["predictions"])

# with those new predictors the precision increases to 54%
# Out:
# 0.5386289445048966

# %%
predictions
# Out:
#             target  predictions
# 2017-09-16       0            1
# 2017-09-17       1            0
# 2017-09-18       0            0
# 2017-09-19       0            1
# 2017-09-20       0            1
# ...            ...          ...
# 2022-09-04       0            1
# 2022-09-05       0            1
# 2022-09-06       1            1
# 2022-09-07       1            1
# 2022-09-08       0            1
#
# [1819 rows x 2 columns]

# %%
# ideas to improove the model:

# 1. tune the XGBoost model with parameter
# 2. find new predictors (e.g., moving avarages)
# 3. find new sentiments: tweets, news websites, etc.
